# %%
from visual_tools import draw_map
map_type_list=['bubble_map','double_bubble_map','tree_map','brace_map','flow_map','multi_flow_map']
path_list=['demo/'+type[:-3]+'demo.md' for type in map_type_list]
for type in map_type_list:
    path='demo/'+type[:-3]+'demo.md'
    save_path='test_results/'+type[:-3]+'demo'
    draw_map(type,path,save_path)
